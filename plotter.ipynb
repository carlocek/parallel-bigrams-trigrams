# %%
import matplotlib.pyplot as plt
#speedup using sequentialTokenizeWords()
parallelTimesBook1 = [0.367482, 0.184253, 0.174118, 0.160794, 0.165408, 0.169788]
sequentialTimesBook1 = [0.367482 for i in range(6)]
sp1 = [sequentialTimesBook1[i]/parallelTimesBook1[i] for i in range(6)]

parallelTimesBook12 = [0.751232, 0.406693, 0.382596, 0.351853, 0.354273, 0.363245]
sequentialTimesBook12 = [0.751232 for i in range(6)]
sp12 = [sequentialTimesBook12[i]/parallelTimesBook12[i] for i in range(6)]

parallelTimesBook123 = [1.790188, 0.933597, 0.807691, 0.736444, 0.737099, 0.744144]
sequentialTimesBook123 = [1.790188 for i in range(6)]
sp123 = [sequentialTimesBook123[i]/parallelTimesBook123[i] for i in range(6)]

parallelTimesBook1234 = [2.781267, 1.475559, 1.303046, 1.169718, 1.154373, 1.179942]
sequentialTimesBook1234 = [2.781267 for i in range(6)]
sp1234 = [sequentialTimesBook1234[i]/parallelTimesBook1234[i] for i in range(6)]

parallelTimesBook12345 = [4.124560, 2.340146, 1.964538, 1.733306, 1.688782, 2.085496]
sequentialTimesBook12345 = [4.124560 for i in range(6)]
sp12345 = [sequentialTimesBook12345[i]/parallelTimesBook12345[i] for i in range(6)]


x = [1, 2, 4, 8, 16, 32]
plt.plot(x, sp1, "o-", label = "1MB")
plt.plot(x, sp12, "o-", label = "2.14MB")
plt.plot(x, sp123, "o-", label = "4.42MB")
plt.plot(x, sp1234, "o-", label = "7.07MB")
plt.plot(x, sp12345, "o-", label = "10.27MB")
plt.xticks(x)
plt.grid(axis="y")
plt.xlabel("number of threads")
plt.ylabel("speedup")
plt.legend()
#plt.savefig("C:\\Users\\carlo\\Desktop\\speedup.png", dpi=200, bbox_inches="tight")
plt.show()

# %%
#speedup using parallelTokenizeWords()
parallelTimesBook1 = [0.367482, 0.151531, 0.135432, 0.121204, 0.125270, 0.128984]
sequentialTimesBook1 = [0.367482 for i in range(6)]
sp1 = [sequentialTimesBook1[i]/parallelTimesBook1[i] for i in range(6)]

parallelTimesBook12 = [0.751232, 0.307222, 0.277954, 0.266856, 0.274418, 0.286901]
sequentialTimesBook12 = [0.751232 for i in range(6)]
sp12 = [sequentialTimesBook12[i]/parallelTimesBook12[i] for i in range(6)]

parallelTimesBook123 = [1.790188, 0.844028, 0.624802, 0.604578, 0.586725, 0.625329]
sequentialTimesBook123 = [1.790188 for i in range(6)]
sp123 = [sequentialTimesBook123[i]/parallelTimesBook123[i] for i in range(6)]

parallelTimesBook1234 = [2.781267, 1.344566, 1.123156, 0.964197, 0.958852, 0.971220]
sequentialTimesBook1234 = [2.781267 for i in range(6)]
sp1234 = [sequentialTimesBook1234[i]/parallelTimesBook1234[i] for i in range(6)]

parallelTimesBook12345 = [4.124560, 1.614211, 1.444236, 1.364431, 1.355117, 1.423496]
sequentialTimesBook12345 = [4.124560 for i in range(6)]
sp12345 = [sequentialTimesBook12345[i]/parallelTimesBook12345[i] for i in range(6)]

x = [1, 2, 4, 8, 16, 32]
plt.plot(x, sp1, "o-", label = "1MB")
plt.plot(x, sp12, "o-", label = "2.14MB")
plt.plot(x, sp123, "o-", label = "4.42MB")
plt.plot(x, sp1234, "o-", label = "7.07MB")
plt.plot(x, sp12345, "o-", label = "10.27MB")
plt.xticks(x)
plt.grid(axis="y")
plt.xlabel("number of threads")
plt.ylabel("speedup")
plt.legend()
#plt.savefig("C:\\Users\\carlo\\Desktop\\speedup_partoken.png", dpi=200, bbox_inches="tight")
plt.show()
